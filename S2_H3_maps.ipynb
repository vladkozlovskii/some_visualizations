# %%
import branca
import geojson
import geopandas as gpd
import folium
import json
import h3
import io
import pandas as pd
import selenium
from s2sphere import CellId, LatLng, Cell
import xarray as xr

from branca.colormap import linear
from folium.plugins import MousePosition
from PIL import Image
from shapely import Polygon

# %%
temp_path = 'C:/Users/vladk/NC_DATA/'

# %%
ds = xr.open_dataset(temp_path + 'gebco_2024_n45.23_s40.85_w36.59_e42.0.nc')
ds = ds.to_dataframe().reset_index()
ds = ds.loc[ds['elevation'] <= 0]
ds
# Out:
#                lat        lon  elevation
# 17300    40.906250  38.368750         -9
# 18595    40.910417  38.356250         -5
# 18596    40.910417  38.360417         -8
# 18597    40.910417  38.364583        -18
# 18598    40.910417  38.368750        -53
# ...            ...        ...        ...
# 1363228  45.227083  37.960417          0
# 1363229  45.227083  37.964583          0
# 1363230  45.227083  37.968750          0
# 1363231  45.227083  37.972917          0
# 1363232  45.227083  37.977083          0
#
# [836842 rows x 3 columns]

# %%
# set sies for h3 and s2 cells (h3: edge length 8.6 km, cell area - 252.9 km^2. s2: edge length 19.5 km, cell area 324.3 km^2)
RES_H3 = 5
RES_S2 = 9

# %%
# function to take h3-index from coordinates 

def convert_to_h3(lat, lon, res):
    h3_index = h3.latlng_to_cell(lat, lon, res)
    return h3_index

def h3_to_table(row):
    lat = row['lat']
    lon = row['lon']
    h3_index = convert_to_h3(lat, lon, RES_H3)
    return h3_index

# %%
# function to get s2 index from coordinates
def s2_to_table(row):
    lat = row['lat']
    lon = row['lon']
    cell_id = CellId.from_lat_lng(LatLng.from_degrees(lat, lon)).parent(RES_S2)
    return cell_id

# %%
# function to get the vertices of an S2 cell
def get_s2_cell_vertices(cell_id):
    cell = Cell(cell_id)
    vertices = []
    # S2 cells have 4 vertices
    for i in range(4):  
        vertex = cell.get_vertex(i)
        latlng = LatLng.from_point(vertex)
        vertices.append((latlng.lat().degrees, latlng.lng().degrees))
    # close the polygon by repeating the first vertex
    vertices.append(vertices[0])
    return vertices

# %%
def s2_index(data, level):
    s2_ind = []
    for lat, lon in zip(data['lat'], data['lon']):
        cell_id = CellId.from_lat_lng(LatLng.from_degrees(lat, lon)).parent(level)
        s2_ind.append(cell_id)
    return s2_ind

# %% [markdown]
# ### apply function to get s2 and h3 indices

# %%
ds['h3'] = ds.apply(h3_to_table, axis=1)

# %%
ds['s2'] = ds.apply(s2_to_table, axis=1)
ds.head()
# Out:
#              lat        lon  elevation               h3  \
# 17300  40.906250  38.368750         -9  852d198ffffffff
# 18595  40.910417  38.356250         -5  852d198ffffffff
# 18596  40.910417  38.360417         -8  852d198ffffffff
# 18597  40.910417  38.364583        -18  852d198ffffffff
# 18598  40.910417  38.368750        -53  852d198ffffffff
#
#                              s2
# 17300  CellId: 40636c0000000000
# 18595  CellId: 40636c0000000000
# 18596  CellId: 40636c0000000000
# 18597  CellId: 40636c0000000000
# 18598  CellId: 40636c0000000000

# %% [markdown]
# # Groupby H3 and S2

# %%
gruopby_s2 = ds.groupby('s2')['elevation'].agg('mean').reset_index()
print(gruopby_s2.shape)
gruopby_s2.head()
# Out:
# (544, 2)
#                          s2   elevation
# 0  CellId: 405c2c0000000000   -6.746032
# 1  CellId: 405d740000000000 -203.142857
# 2  CellId: 405d7c0000000000 -422.950748
# 3  CellId: 405d840000000000 -671.451688
# 4  CellId: 405d8c0000000000 -846.132251

# %%
# get centroids of s2 cells (not for this case)
gruopby_s2['s2_center'] = gruopby_s2['s2'].apply(lambda x: x.to_lat_lng()) 
gruopby_s2['lat'] = gruopby_s2['s2_center'].apply(lambda x: x.lat().degrees)
gruopby_s2['lon'] = gruopby_s2['s2_center'].apply(lambda x: x.lng().degrees)
gruopby_s2 = gruopby_s2.drop('s2_center', axis=1)
gruopby_s2.head()
# Out:
#                          s2   elevation        lat        lon
# 0  CellId: 405c2c0000000000   -6.746032  42.452719  41.659935
# 1  CellId: 405d740000000000 -203.142857  41.851886  41.878679
# 2  CellId: 405d7c0000000000 -422.950748  41.759397  41.712283
# 3  CellId: 405d840000000000 -671.451688  41.838510  41.533093
# 4  CellId: 405d8c0000000000 -846.132251  41.917415  41.353298

# %%
gruopby_h3 = ds.groupby('h3')['elevation'].agg('mean').reset_index()
print(gruopby_h3.shape)
gruopby_h3.head()
# Out:
# (587, 2)
#                 h3    elevation
# 0  852c2003fffffff  -850.963636
# 1  852c2007fffffff  -784.128542
# 2  852c2013fffffff -1499.480708
# 3  852c2017fffffff -1562.995570
# 4  852c201bfffffff  -138.766756

# %%
# get centroids of h3 cells (not for this case)
gruopby_h3['h3_center'] = gruopby_h3['h3'].apply(lambda x: h3.cell_to_latlng(x)) #    old variants:   h3_to_geo      cellToLatLng 
gruopby_h3['h3_center'] = gruopby_h3['h3_center'].apply(lambda x: (x[1], x[0]))
gruopby_h3['lon'] = gruopby_h3['h3_center'].apply(lambda x: x[0])
gruopby_h3['lat']  = gruopby_h3['h3_center'].apply(lambda x: x[1])
gruopby_h3 = gruopby_h3.drop('h3_center', axis=1)
gruopby_h3.head()
# Out:
#                 h3    elevation        lon        lat
# 0  852c2003fffffff  -850.963636  41.050988  41.256344
# 1  852c2007fffffff  -784.128542  41.184178  41.367969
# 2  852c2013fffffff -1499.480708  40.850979  41.294263
# 3  852c2017fffffff -1562.995570  40.984170  41.406152
# 4  852c201bfffffff  -138.766756  40.918009  41.144362

# %% [markdown]
# ### Prepare geojson
# h3 and s2 have other invert order of lat-lon and i need to change order to save it in geojson

# %%
gruopby_s2['g_reflect'] = gruopby_s2['s2'].apply(lambda x: get_s2_cell_vertices(x))
gruopby_s2.head()
# Out:
#                          s2   elevation        lat        lon  \
# 0  CellId: 405c2c0000000000   -6.746032  42.452719  41.659935
# 1  CellId: 405d740000000000 -203.142857  41.851886  41.878679
# 2  CellId: 405d7c0000000000 -422.950748  41.759397  41.712283
# 3  CellId: 405d840000000000 -671.451688  41.838510  41.533093
# 4  CellId: 405d8c0000000000 -846.132251  41.917415  41.353298
#
#                                            g_reflect
# 0  [(42.365363255296955, 41.66658104153733), (42....
# 1  [(41.76588469518899, 41.884785238675505), (41....
# 2  [(41.67361862988219, 41.71869698464216), (41.7...
# 3  [(41.752562383928066, 41.539871424697346), (41...
# 4  [(41.83129961290025, 41.36044296593703), (41.9...

# %%
result_g2 = []
for i in gruopby_s2['g_reflect']:
    iter = []
    for a in i:
        int = tuple([a[1], a[0]])
        iter.append(int)
    iter = tuple(iter)
    c = Polygon(iter)
    polygon = Polygon(iter)
    result_g2.append(c)
gruopby_s2['geometry'] = result_g2
gruopby_s2 = gruopby_s2.drop('g_reflect', axis=1)
gruopby_s2.head()
# Out:
#                          s2   elevation        lat        lon  \
# 0  CellId: 405c2c0000000000   -6.746032  42.452719  41.659935
# 1  CellId: 405d740000000000 -203.142857  41.851886  41.878679
# 2  CellId: 405d7c0000000000 -422.950748  41.759397  41.712283
# 3  CellId: 405d840000000000 -671.451688  41.838510  41.533093
# 4  CellId: 405d8c0000000000 -846.132251  41.917415  41.353298
#
#                                             geometry
# 0  POLYGON ((41.66658104153733 42.365363255296955...
# 1  POLYGON ((41.884785238675505 41.76588469518899...
# 2  POLYGON ((41.71869698464216 41.67361862988219,...
# 3  POLYGON ((41.539871424697346 41.75256238392806...
# 4  POLYGON ((41.36044296593703 41.83129961290025,...

# %%
gruopby_h3['g_reflect'] = gruopby_h3['h3'].apply(lambda x: h3.cell_to_boundary(x))   # old variant  cellToBoundary 
gruopby_h3.head()
# Out:
#                 h3    elevation        lon        lat  \
# 0  852c2003fffffff  -850.963636  41.050988  41.256344
# 1  852c2007fffffff  -784.128542  41.184178  41.367969
# 2  852c2013fffffff -1499.480708  40.850979  41.294263
# 3  852c2017fffffff -1562.995570  40.984170  41.406152
# 4  852c201bfffffff  -138.766756  40.918009  41.144362
#
#                                            g_reflect
# 0  ((41.31896349151986, 40.96207512917783), (41.2...
# 1  ((41.43064512690874, 41.09533682575575), (41.3...
# 2  ((41.35676988928988, 40.76174730576111), (41.2...
# 3  ((41.46871645093721, 40.89500778895924), (41.3...
# 4  ((41.206923486596665, 40.82902657588255), (41....

# %%
result_g2 = []
for i in gruopby_h3['g_reflect']:
    iter = []
    for a in i:
        int = tuple([a[1], a[0]])
        iter.append(int)
    iter = tuple(iter)
    c = Polygon(iter)
    polygon = Polygon(iter)
    result_g2.append(c)
gruopby_h3['geometry'] = result_g2
gruopby_h3 = gruopby_h3.drop('g_reflect', axis=1)
gruopby_h3.head()
# Out:
#                 h3    elevation        lon        lat  \
# 0  852c2003fffffff  -850.963636  41.050988  41.256344
# 1  852c2007fffffff  -784.128542  41.184178  41.367969
# 2  852c2013fffffff -1499.480708  40.850979  41.294263
# 3  852c2017fffffff -1562.995570  40.984170  41.406152
# 4  852c201bfffffff  -138.766756  40.918009  41.144362
#
#                                             geometry
# 0  POLYGON ((40.96207512917783 41.31896349151986,...
# 1  POLYGON ((41.09533682575575 41.43064512690874,...
# 2  POLYGON ((40.76174730576111 41.35676988928988,...
# 3  POLYGON ((40.89500778895924 41.46871645093721,...
# 4  POLYGON ((40.82902657588255 41.206923486596665...

# %%
# save dataframes into .geojson for use it in GIS or in other purposes
gruopby_s2 = gpd.GeoDataFrame(gruopby_s2, geometry=gruopby_s2['geometry'], crs="EPSG:4326")
gruopby_s2.to_file('s2.geojson', driver="GeoJSON")
gruopby_h3 = gpd.GeoDataFrame(gruopby_h3, geometry=gruopby_h3['geometry'], crs="EPSG:4326")
gruopby_h3.to_file('h3.geojson', driver="GeoJSON")

# %% [markdown]
# # MAP

# %% [markdown]
# Here visulaisation of dataframes (by separate polygons and using whole .geojson)

# %%
map_s2 = folium.Map(location=[42.5, 39.8], zoom_start=7)

# %%
colormap = branca.colormap.LinearColormap(colors=['cyan', 'green', 'yellow', 'orange','red'],
                            vmin=round(gruopby_s2['elevation'].min(), 2), vmax=round(gruopby_s2['elevation'].max(), 2),
                             caption='elevation')

for i, a in zip(gruopby_s2['s2'], gruopby_s2['elevation']):
    vertices = get_s2_cell_vertices(i)
    
    folium.Polygon(
        locations=vertices,
        color=colormap(a),
        weight=2,
        fill=True,
        fill_color=colormap(a),
        fill_opacity=0.5,
        popup=a,
        legend=True
    ).add_to(map_s2)

map_s2.add_child(colormap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41b76dd2c6cba7ee0f8a5f6b5c061427 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41b76dd2c6cba7ee0f8a5f6b5c061427&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41b76dd2c6cba7ee0f8a5f6b5c061427 = L.map(
#                 &quot;map_41b76dd2c6cba7ee0f8a5f6b5c061427&quot;,
#                 {
#                     center: [42.5, 39.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99786d119e75f22f008a3e1c444cc0cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99786d119e75f22f008a3e1c444cc0cc.addTo(map_41b76dd2c6cba7ee0f8a5f6b5c061427);
#
#
#             var polygon_e33491b9d0cbf2869010279c822a6d0c = L.polygon(
#                 [[42.365363255296955, 41.66658104153733], [42.459418574238434, 41.8351684135353], [42.54027313076487, 41.65325973598033], [42.44566140220923, 41.484797652630874], [42.365363255296955, 41.66658104153733]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0200ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0200ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_41b76dd2c6cba7ee0f8a5f6b5c061427);
#
#
#         var popup_fa14720e54adf38779a03dfdbb26d3f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4770a2db3d4759835601adb0d2baccb9 = $(`&lt;div id=&quot;html_4770a2db3d4759835601adb0d2baccb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;-6.746031746031746&lt;/div&gt;`)[0];
#                 popup_fa14720e54adf38779a03dfdbb26d3f6.setContent(html_4770a2db3d4759835601adb0d2baccb9);
#
#
#
#         polygon_e33491b9d0cbf2869010279c822a6d0c.bindPopup(popup_fa14720e54adf38779a03dfdbb26d3f6)
#         ;
#
#
#
#
#             var polygon_b73047440dbb7ca696361bcff23e626b = L.polygon(
#                 [[41.76588469518899, 41.884785238675505], [41.858050389177116, 42.051604467753016], [41.93808451601908, 41.872545423525274], [41.845372571472836, 41.70584017552234], [41.76588469518899, 41.884785238675505]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff3e00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff3e00ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_41b76dd2c6cba7ee0f8a5f6b5c061427);
#
#
#         var popup_ac01a179433df5b6459268054f7378e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53b63b4fcbf35081d031e96a82548569 = $(`&lt;div id=&quot;html_53b63b4fcbf35081d031e96a82548569&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;-203.14285714285714&lt;/div&gt;`)[0];
#                 popup_ac01a179433df5b6459268054f7378e2.setContent(html_53b63b4fcbf35081d031e96a82548569);
#
#
#
#         polygon_b73047440dbb7ca696361bcff23e626b.bindPopup(popup_ac01a179433df5b6459268054f7378e2)
#         ;
#
#
#
#
#             var polygon_24fd37baf9e604ab015bdd17b2f4bc6b = L.polygon(
#                 [[41.67361862988219, 41.71869698464216], [41.76588469518899, 41.884785238675505], [41.845372571472836, 41.70584017552234], [41.752562383928066, 41.539871424697346], [41.67361862988219, 41.71869698464216]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff8100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff8100ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_41b76dd2c6cba7ee0f8a5f6b5c061427);
#
#
#         var popup_30df729733677a86c3be974ec209071a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e2bcc0b20d90

# %%
colormap = branca.colormap.LinearColormap(colors=['cyan', 'green', 'yellow', 'orange','red'],
                            vmin=round(gruopby_h3['elevation'].min(), 2), vmax=round(gruopby_h3['elevation'].max(), 2),
                             caption='depth')

start = 0
for i in range(len(gruopby_h3)):
    hex_coord = h3.cell_to_boundary(gruopby_h3['h3'].iloc[i])
    meaninig_in_point = gruopby_h3['elevation'].iloc[i]
    map_center = [hex_coord[0][0], hex_coord[0][1]]
    if start == 0:
        map_h3 = folium.Map(location=map_center, zoom_start=7, crs='EPSG3857')
        start = 1
    folium.Polygon(locations=hex_coord, color=colormap(meaninig_in_point), fill=True, fill_color=colormap(meaninig_in_point), fill_opacity=0.6, popup=round(gruopby_h3['elevation'].iloc[i], 2), legend=True).add_to(map_h3)     

map_h3.add_child(colormap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed9bd0386aa415cf9a72f511e777f2d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed9bd0386aa415cf9a72f511e777f2d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed9bd0386aa415cf9a72f511e777f2d2 = L.map(
#                 &quot;map_ed9bd0386aa415cf9a72f511e777f2d2&quot;,
#                 {
#                     center: [41.31896349151986, 40.96207512917783],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2bb1580bfd57a5f0294708ca3a0ea72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2bb1580bfd57a5f0294708ca3a0ea72.addTo(map_ed9bd0386aa415cf9a72f511e777f2d2);
#
#
#             var polygon_918dcdfa844530093ca3cfa84feff36e = L.polygon(
#                 [[41.31896349151986, 40.96207512917783], [41.23169982478553, 40.94002172396789], [41.16908181178416, 41.02887493425153], [41.19367058926073, 41.13971063153433], [41.280857344916676, 41.16192348369955], [41.34353230530588, 41.073141561003624]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffd900ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffd900ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed9bd0386aa415cf9a72f511e777f2d2);
#
#
#         var popup_d9dd4929ccd2d29effde8c683a129d4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13ef984de0d73d0d363abace7fb2be08 = $(`&lt;div id=&quot;html_13ef984de0d73d0d363abace7fb2be08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;-850.96&lt;/div&gt;`)[0];
#                 popup_d9dd4929ccd2d29effde8c683a129d4d.setContent(html_13ef984de0d73d0d363abace7fb2be08);
#
#
#
#         polygon_918dcdfa844530093ca3cfa84feff36e.bindPopup(popup_d9dd4929ccd2d29effde8c683a129d4d)
#         ;
#
#
#
#
#             var polygon_7ccce5ccab9013fa3103ef8a6318621f = L.polygon(
#                 [[41.43064512690874, 41.09533682575575], [41.34353230530588, 41.073141561003624], [41.280857344916676, 41.16192348369955], [41.30523868707969, 41.27282845558329], [41.392274417508325, 41.29518276071212], [41.45500596749609, 41.20647342525632]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffce00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffce00ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed9bd0386aa415cf9a72f511e777f2d2);
#
#
#         var popup_b310c2dafe4ff098587ec0b11109776e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_025b557591d0752ec0267255f9d2469b = $(`&lt;div id=&quot;html_025b557591d0752ec0267255f9d2469b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;-784.13&lt;/div&gt;`)[0];
#                 popup_b310c2dafe4ff098587ec0b11109776e.setContent(html_025b557591d0752ec0267255f9d2469b);
#
#
#
#         polygon_7ccce5ccab9013fa3103ef8a6318621f.bindPopup(popup_b310c2dafe4ff098587ec0b11109776e)
#         ;
#
#
#
#
#             var polygon_2055f644257417086def2f6213517506 = L.polygon(
#                 [[41.35676988928988, 40.76174730576111], [41.2694299470149, 40.739854714807265], [41.206923486596665, 40.82902657588255], [41.23169982478553, 40.94002172396789], [41.31896349151986, 40.96207512917783], [41.381527168318684, 40.87297294058547]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3b9e00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3b9e00ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed9bd0386aa415cf9a72f511e777f2d2);
#
#
#         var popup_4844e25f4f1567bbcc57a8c8630f0a58 = L

# %%
# save one of the maps
img_data = map_h3._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('08_map_h3.png')

# %% [markdown]
# ### building maps using whole .geojson

# %%
with open('h3.geojson') as file:
    gj = geojson.load(file)
gj
# Out:
# {"crs": {"properties": {"name": "urn:ogc:def:crs:OGC:1.3:CRS84"}, "type": "name"}, "features": [{"geometry": {"coordinates": [[[40.962075, 41.318963], [40.940022, 41.2317], [41.028875, 41.169082], [41.139711, 41.193671], [41.161923, 41.280857], [41.073142, 41.343532], [40.962075, 41.318963]]], "type": "Polygon"}, "properties": {"elevation": -850.9636363636364, "h3": "852c2003fffffff", "lat": 41.25634441802905, "lon": 41.05098763342498}, "type": "Feature"}, {"geometry": {"coordinates": [[[41.095337, 41.430645], [41.073142, 41.343532], [41.161923, 41.280857], [41.272828, 41.305239], [41.295183, 41.392274], [41.206473, 41.455006], [41.095337, 41.430645]]], "type": "Polygon"}, "properties": {"elevation": -784.1285418106427, "h3": "852c2007fffffff", "lat": 41.36796925284935, "lon": 41.1841777119463}, "type": "Feature"}, {"geometry": {"coordinates": [[[40.761747, 41.35677], [40.739855, 41.26943], [40.829027, 41.206923], [40.940022, 41.2317], [40.962075, 41.318963], [40.872973, 41.381527], [40.761747, 41.35677]]], "type": "Polygon"}, "properties": {"elevation": -1499.4807084123972, "h3": "852c2013fffffff", "lat": 41.29426273117589, "lon": 40.85097923912089}, "type": "Feature"}, {"geometry": {"coordinates": [[[40.895008, 41.468716], [40.872973, 41.381527], [40.962075, 41.318963], [41.073142, 41.343532], [41.095337, 41.430645], [41.006306, 41.493266], [40.895008, 41.468716]]], "type": "Polygon"}, "properties": {"elevation": -1562.9955696202533, "h3": "852c2017fffffff", "lat": 41.40615222119682, "lon": 40.98416972261369}, "type": "Feature"}, {"geometry": {"coordinates": [[[40.829027, 41.206923], [40.807115, 41.11951], [40.896038, 41.056949], [41.006803, 41.081745], [41.028875, 41.169082], [40.940022, 41.2317], [40.829027, 41.206923]]], "type": "Polygon"}, "properties": {"elevation": -138.76675603217157, "h3": "852c201bfffffff", "lat": 41.14436156884323, "lon": 40.918009398434194}, "type": "Feature"}, {"geometry": {"coordinates": [[[41.428652, 41.503332], [41.406156, 41.416448], [41.494542, 41.353607], [41.60535, 41.377594], [41.628003, 41.4644], [41.539692, 41.527297], [41.428652, 41.503332]]], "type": "Polygon"}, "properties": {"elevation": -69.09923664122137, "h3": "852c2023fffffff", "lat": 41.44048974673385, "lon": 41.51709627354386}, "type": "Feature"}, {"geometry": {"coordinates": [[[41.56233, 41.614028], [41.539692, 41.527297], [41.628003, 41.4644], [41.738876, 41.488179], [41.76167, 41.574832], [41.673436, 41.637785], [41.56233, 41.614028]]], "type": "Polygon"}, "properties": {"elevation": -21.404761904761905, "h3": "852c2027fffffff", "lat": 41.55113042565121, "lon": 41.65069834046242}, "type": "Feature"}, {"geometry": {"coordinates": [[[41.228811, 41.541967], [41.206473, 41.455006], [41.295183, 41.392274], [41.406156, 41.416448], [41.428652, 41.503332], [41.340016, 41.56612], [41.228811, 41.541967]]], "type": "Polygon"}, "properties": {"elevation": -741.368253968254, "h3": "852c2033fffffff", "lat": 41.47923482804384, "lon": 41.31757869773075}, "type": "Feature"}, {"geometry": {"coordinates": [[[41.362496, 41.652928], [41.340016, 41.56612], [41.428652, 41.503332], [41.539692, 41.527297], [41.56233, 41.614028], [41.473769, 41.676872], [41.362496, 41.652928]]], "type": "Polygon"}, "properties": {"elevation": -555.6369993642721, "h3": "852c2037fffffff", "lat": 41.59013992079115, "lon": 41.451189642397104}, "type": "Feature"}, {"geometry": {"coordinates": [[[41.295183, 41.392274], [41.272828, 41.305239], [41.361289, 41.242454], [41.472031, 41.266649], [41.494542, 41.353607], [41.406156, 41.416448], [41.295183, 41.392274]]], "type": "Polygon"}, "properties": {"elevation": -40.59607843137255, "h3": "852c203bfffffff", "lat": 41.32948852917732, "lon": 41.38370173124942}, "type": "Feature"}, {"geometry": {"coordinates": [[[40.492913, 41.54395], [40.471203, 41.45661], [40.560943, 41.394274], [40.672326, 41.419221], [40.694199, 41.506486], [40.604527, 41.568879], [40.492913, 41.54395]]], "type": "Polygon"}, "properties": {"elevation": -1705 ...

# %%
gdf = gpd.read_file('h3.geojson')
gdf.head(2)
# Out:
#                 h3   elevation        lon        lat  \
# 0  852c2003fffffff -850.963636  41.050988  41.256344
# 1  852c2007fffffff -784.128542  41.184178  41.367969
#
#                                             geometry
# 0  POLYGON ((40.96208 41.31896, 40.94002 41.2317,...
# 1  POLYGON ((41.09534 41.43065, 41.07314 41.34353...

# %%
colormap = linear.YlGn_09.scale(
    gdf['elevation'].min(), gdf['elevation'].max()
)

map_h3 = folium.Map(location=[42.5, 39.8], zoom_start=7)

folium.GeoJson(gj, 
               style_function=lambda feature: {
                    "fillColor": colormap(feature["properties"]["elevation"]),
                    "color": colormap(feature["properties"]["elevation"]),
                    "weight": 2,
                    "dashArray": "5, 5",
                    "fillOpacity": 0.7,
                    "Opacity" : 0.7,
    },
).add_to(map_h3)


formatter = "function(num) {return L.Util.formatNum(num, 3) + ' º ';};"

MousePosition(
    position="topright",
    separator=" | ",
    empty_string="NaN",
    lng_first=True,
    num_digits=20,
    prefix="Coordinates:",
    lat_formatter=formatter,
    lng_formatter=formatter,
).add_to(map_s2)

colormap.add_to(map_h3)
map_h3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0998563f754cc920f2bcf0b8be224f3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0998563f754cc920f2bcf0b8be224f3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0998563f754cc920f2bcf0b8be224f3a = L.map(
#                 &quot;map_0998563f754cc920f2bcf0b8be224f3a&quot;,
#                 {
#                     center: [42.5, 39.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc916f47c3ba64940fade817bd3c83e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc916f47c3ba64940fade817bd3c83e2.addTo(map_0998563f754cc920f2bcf0b8be224f3a);
#
#
#         function geo_json_62264d1165dd2e33c589980d3de7cd98_styler(feature) {
#             switch(feature.properties.h3) {
#                 case &quot;852c2003fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#49af61ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#49af61ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2007fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#3ea75aff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#3ea75aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2013fffffff&quot;: case &quot;852d0e0ffffffff&quot;: case &quot;852d19a7fffffff&quot;: case &quot;852d569bfffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#c5e899ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#c5e899ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2017fffffff&quot;: case &quot;852c250ffffffff&quot;: case &quot;852d764bfffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#cfec9eff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#cfec9eff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c201bfffffff&quot;: case &quot;852d567bfffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#005730ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#005730ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2023fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#004e2cff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#004e2cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2027fffffff&quot;: case &quot;852d1d17fffffff&quot;: case &quot;852d7293fffffff&quot;: case &quot;852d7617fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#00482aff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#00482aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2033fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#39a156ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#39a156ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2037fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#248644ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#248644ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c203bfffffff&quot;: case &quot;852d1d2bfffffff&quot;: case &quot;852d54d3fffffff&quot;: case &quot;852d566ffffffff&quot;: case &quot;852d728bfffffff&quot;: case &quot;852d762bfffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#004a2bff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#004a2bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2083fffffff&quot;: case &quot;852c2543fffffff&quot;: case &quot;852d0acbfffffff&quot;: case &quot;852d19b7fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#e2f4aaff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#e2f4aaff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;852c2087fffffff&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#d6efa1ff&quot;, &q

# %%
with open('s2.geojson') as file:
    gj = geojson.load(file)
gdf = gpd.read_file('s2.geojson')

colormap = linear.YlGn_09.scale(
    gdf['elevation'].min(), gdf['elevation'].max()
)

map_s2 = folium.Map(location=[42.5, 39.8], zoom_start=7)

folium.GeoJson(gj, 
               style_function=lambda feature: {
                    "fillColor": colormap(feature["properties"]["elevation"]),
                    "color": colormap(feature["properties"]["elevation"]),
                    "weight": 2,
                    "dashArray": "5, 5",
                    "fillOpacity": 0.7,
                    "Opacity" : 0.7,
    },
).add_to(map_s2)


formatter = "function(num) {return L.Util.formatNum(num, 3) + ' º ';};"

MousePosition(
    position="topright",
    separator=" | ",
    empty_string="NaN",
    lng_first=True,
    num_digits=20,
    prefix="Coordinates:",
    lat_formatter=formatter,
    lng_formatter=formatter,
).add_to(map_s2)

colormap.add_to(map_s2)
map_s2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cf7d3ba8341225a8bb049cf0f59bc55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cf7d3ba8341225a8bb049cf0f59bc55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cf7d3ba8341225a8bb049cf0f59bc55 = L.map(
#                 &quot;map_5cf7d3ba8341225a8bb049cf0f59bc55&quot;,
#                 {
#                     center: [42.5, 39.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74d4d4d8121f1621689df36ab522252c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74d4d4d8121f1621689df36ab522252c.addTo(map_5cf7d3ba8341225a8bb049cf0f59bc55);
#
#
#         function geo_json_6909ba9a2df2609cdfc0b7d2aa947f5d_styler(feature) {
#             switch(feature.properties.s2) {
#                 case &quot;CellId: 405c2c0000000000&quot;: case &quot;CellId: 405e9c0000000000&quot;: case &quot;CellId: 4063240000000000&quot;: case &quot;CellId: 40678c0000000000&quot;: case &quot;CellId: 40ee640000000000&quot;: case &quot;CellId: 40ee840000000000&quot;: case &quot;CellId: 40f18c0000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#004629ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#004629ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405d740000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#005f33ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#005f33ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405d7c0000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#13783dff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#13783dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405d840000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#31974fff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#31974fff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405d8c0000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#47ae60ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#47ae60ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405d940000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#1c7e40ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#1c7e40ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405d9c0000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#006033ff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#006033ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405da40000000000&quot;: case &quot;CellId: 405e940000000000&quot;: case &quot;CellId: 40ec2c0000000000&quot;: case &quot;CellId: 40ee0c0000000000&quot;: case &quot;CellId: 40f1f40000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#00482aff&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#00482aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;CellId: 405db40000000000&quot;: case &quot;CellId: 405f3c0000000000&quot;: case &quot;CellId: 4062dc0000000000&quot;: case &quot;CellId: 4088740000000000&quot;: case &quot;CellId: 40ee240000000000&quot;: case &quot;CellId: 40ee2c0000000000&quot;: case &quot;CellId: 40ee340000000000&quot;: case &quot;CellId: 40ee3c0000000000&quot;: case &quot;CellId: 40ee440000000000&quot;: case &quot;CellId: 40ee4c0000000000&quot;: case &quot;CellId: 40ee5c0000000000&quot;: case &quot;CellId: 40ee6c0000000000&quot;: case &quot;CellId: 40ee8c0000000000&quot;: case &quot;CellId: 40ee940000000000&quot;: case &quot;CellId: 40ee9c0000000000&quot;: case &quot;CellId: 40f1d40000000000&quot;:
#                     return {&quot;Opacity&quot;: 0.7, &quot;color&quot;: &quot;#004529ff&
